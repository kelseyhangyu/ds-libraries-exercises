# %% [markdown]
# # Create and label 4 separate charts with the following equations (choose a range for x that makes sense):
#
# y = √x
# y = x^3
# y = 2^x
# y = 1/(x + 1)
#
# # You can use functions from the math module to help implement some of the equations above.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = pd.Series(range(50))
y1 = x1 ** 0.5
plt.plot(x1,y1)

# %%
x2 = pd.Series(range(50))
y2 = x2 ** 3
plt.plot(x2,y2)

# %%
x3 = pd.Series(range(50))
y3 = 2 ** x3
plt.plot(x3,y3)

# %%
x4 = pd.Series(range(50))
y4 = 1/(x + 1)
plt.plot(x4,y4)

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)
plt.show()

# %% [markdown]
# # Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(10,6))

plt.subplot(221)
plt.plot(x1,y1)

plt.subplot(222)
plt.plot(x2,y2)

plt.subplot(223)
plt.plot(x3,y3)

plt.subplot(224)
plt.plot(x4,y4)

plt.suptitle('test')
plt.show()

# %%
fig, ax = plt.subplots(2,2) #initialize at the top with the plt.subplots()

ax[0,0].plot(x1,y1) #call the ax variable and plot on it
ax[0,1].plot(x2,y2)
ax[1,0].plot(x3,y3)
ax[1,1].plot(x4,y4)



plt.tight_layout()
plt.show()
